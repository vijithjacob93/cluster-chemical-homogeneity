# %%
import imp
import numpy as np

from clusterchemistry.classes import fits_file, Cluster
# imp.reload(classes)
# from classes import fits_file, Cluster

from clusterchemistry.functions import Complete_Clusters_func, cluster_membership
# imp.reload(functions)
# from functions import Complete_Clusters_func, cluster_membership

from astropy.table import Table
from astropy import table

# %% [markdown]
# # Find cluster members

# %%
#read the DR156 file. Default=current directory. Replace with required directory if needed.
DR16 = fits_file('allStar-r12-l33.fits', 'default')
data_new = DR16.data
#read the distance data
distance_data = fits_file("cbj_spectroPhotom_allStar_dr16beta_order.fits", 'default')        
data_new['D2_med'] = distance_data.data['D2_med']
#quality cuts
data_new = data_new[np.logical_and(data_new['VERR']<4,data_new['VSCATTER']<1)]
#read the Kharchenko catalog
Complete_Clusters = Complete_Clusters_func()
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
# membership for each cluster
cluster_membership('NGC 6819',data_new)
# Out:
#
# NGC 6819  Central stars= 88 ; Annulus Stars= 47  Total stars= 166
# Found merged files
# PM RA center -2.928738789353535
# PM DEC center -3.875769618297223
# RV center 2.6566337614032784
# C:\Users\vijit\Documents\Repositories\clusterchemistry\clusterchemistry\functions.py:276: RuntimeWarning: divide by zero encountered in log
#   return np.sqrt(-2*np.log(probs))
# C:\Users\vijit\Documents\Repositories\clusterchemistry\clusterchemistry\functions.py:388: RuntimeWarning: divide by zero encountered in log
#   prob_total=np.exp((A1*w1*np.log(prob_RV)+A2*w2*np.log(prob_PM))/(A1*w1+A2*w2))
# Number of cluster stars= 61
# age =  9.21
# 1.0

# %% [markdown]
# # Concatenate all the membership info

# %%
#Find the first cluster with membership info
for j in range(1,len(Complete_Clusters)):
#     if (Complete_Clusters.loc[j]['CLUSTER_STATUS']=='              '):
        try:
            f=Table.read("../data/membership_selection/"+\
                         Complete_Clusters['NAME'][j]+"_members_and_background_Kharchenko.dat",format='ascii')
            break
        except:
            pass
#define the full table
full_table=f
#iterate over other membership info and add to full table
for i in range(j+1,len(Complete_Clusters)):
#     if (Complete_Clusters.loc[i]['CLUSTER_STATUS']=='              '):
        try:
            filename="../data/membership_selection/"+\
                                    Complete_Clusters['NAME'][i]+"_members_and_background_Kharchenko.dat"
            f=Table.read(filename,format='ascii')
            full_table= table.vstack([full_table,f])
        except:
            pass

# %%
full_table
# Out:
# <Table length=32133>
#     Cluster          APOGEE_ID          RA     ...    dist_center     log_age
#      str17             str18         float64   ...      float64       float64
# ---------------- ------------------ ---------- ... ------------------ -------
#  AH03 J0822-36.4 2M08205220-3627199 125.217527 ... 15.605498194273576   8.915
#  AH03 J0822-36.4 2M08210351-3615248 125.264644 ... 15.795369147067102   8.915
#  AH03 J0822-36.4 2M08210446-3617183 125.268619 ... 14.641587020211327   8.915
#  AH03 J0822-36.4 2M08211189-3614112 125.299566 ... 15.219426087330964   8.915
#  AH03 J0822-36.4 2M08211695-3615099 125.320633 ...  13.80773112441297   8.915
#  AH03 J0822-36.4 2M08211919-3620402 125.329999 ...  10.53602015460148   8.915
#  AH03 J0822-36.4 2M08211955-3614115 125.331494 ... 14.101086331519634   8.915
#  AH03 J0822-36.4 2M08212588-3614401 125.357848 ... 12.884453801523012   8.915
#  AH03 J0822-36.4 2M08213587-3630144 125.399492 ...  8.816411707467577   8.915
#  AH03 J0822-36.4 2M08213602-3625053 125.400087 ...  6.545118511949252   8.915
#              ...                ...        ... ...                ...     ...
# VDBERGH-HAGEN 87 2M10052009-5535316  151.33374 ... 12.748312304990838     7.3
# VDBERGH-HAGEN 87 2M10052203-5531167 151.341814 ...  9.562652536016746     7.3
# VDBERGH-HAGEN 87 2M10052655-5535159 151.360634 ... 13.026215247461108     7.3
# VDBERGH-HAGEN 87 2M10053093-5513291 151.378912 ... 13.766887641106663     7.3
# VDBERGH-HAGEN 87 2M10053450-5532151 151.393761 ... 11.518124417921756     7.3
# VDBERGH-HAGEN 87 2M10054078-5534423 151.419951 ... 13.866211689698623     7.3
# VDBERGH-HAGEN 87 2M10054523-5519237 151.438492 ...  11.40688268274117     7.3
# VDBERGH-HAGEN 87 2M10055369-5527224 151.473732 ... 11.671007475249146     7.3
# VDBERGH-HAGEN 87 2M10055967-5523112 151.498641 ... 12.274954459814756     7.3
# VDBERGH-HAGEN 87 2M10060471-5526493 151.519642 ...  13.09032655590756     7.3

# %%
#save full table of cluster membership
# full_table.write('../data/Cluster_members.fits',format='fits',overwrite=False)
